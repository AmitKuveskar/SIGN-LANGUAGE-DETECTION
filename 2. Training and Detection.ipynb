# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet_tuned' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %%
#if os.name=='nt':
#    !pip install wget
#    import wget

# %%
#if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
 #   !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# Running tests under Python 3.8.9: C:\Users\Amit\Desktop\BEProject\tfod\Scripts\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-02-13 16:45:34.351978: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-13 16:45:34.961255: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3991 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660, pci bus id: 0000:01:00.0, compute capability: 7.5
# C:\Users\Amit\Desktop\BEProject\tfod\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\model_builder.py:1100: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W0213 16:45:35.418734 16492 model_builder.py:1100] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.31s
# I0213 16:45:35.660598 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.31s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 1.37s
# I0213 16:45:37.034501 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 1.37s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.25s
# I0213 16:45:37.285232 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.25s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.32s
# I0213 16:45:37.606039 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.32s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.6s
# I0213 16:45:39.208377 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.6s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0213 16:45:39.209397 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# I0213 16:45:39.232387 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I0213 16:45:39.246386 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# I0213 16:45:39.262370 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.09s
# I0213 16:45:39.354317 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.08s
# I0213 16:45:39.439269 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.08s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.09s
# I0213 16:45:39.531226 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.09s
# I0213 16:45:39.619176 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.09s
# I0213 16:45:39.709132 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# I0213 16:45:39.736100 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0213 16:45:40.027943 16492 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0213 16:45:40.028943 16492 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 64
# I0213 16:45:40.028943 16492 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 3
# I0213 16:45:40.030942 16492 efficientnet_model.py:144] round_filter input=32 output=32
# I0213 16:45:40.045933 16492 efficientnet_model.py:144] round_filter input=32 output=32
# I0213 16:45:40.045933 16492 efficientnet_model.py:144] round_filter input=16 output=16
# I0213 16:45:40.098902 16492 efficientnet_model.py:144] round_filter input=16 output=16
# I0213 16:45:40.098902 16492 efficientnet_model.py:144] round_filter input=24 output=24
# I0213 16:45:40.235825 16492 efficientnet_model.py:144] round_filter input=24 output=24
# I0213 16:45:40.236830 16492 efficientnet_model.py:144] round_filter input=40 output=40
# I0213 16:45:40.376734 16492 efficientnet_model.py:144] round_filter input=40 output=40
# I0213 16:45:40.377733 16492 efficientnet_model.py:144] round_filter input=80 output=80
# I0213 16:45:40.589613 16492 efficientnet_model.py:144] round_filter input=80 output=80
# I0213 16:45:40.589613 16492 efficientnet_model.py:144] round_filter input=112 output=112
# I0213 16:45:40.801501 16492 efficientnet_model.py:144] round_filter input=112 output=112
# I0213 16:45:40.801501 16492 efficientnet_model.py:144] round_filter input=192 output=192
# I0213 16:45:41.079332 16492 efficientnet_model.py:144] round_filter input=192 output=192
# I0213 16:45:41.079332 16492 efficientnet_model.py:144] round_filter input=320 output=320
# I0213 16:45:41.146310 16492 efficientnet_model.py:144] round_filter input=1280 output=1280
# I0213 16:45:41.174295 16492 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0213 16:45:41.223260 16492 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0213 16:45:41.223260 16492 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 88
# I0213 16:45:41.223260 16492 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 4
# I0213 16:45:41.224260 16492 efficientnet_model.py:144] round_filter input=32 output=32
# I0213 16:45:41.239251 16492 efficientnet_model.py:144] round_filter input=32 output=32
# I0213 16:45:41.239251 16492 efficientnet_model.py:144] round_filter input=16 output=16
# I0213 16:45:41.355185 16492 efficientnet_model.py:144] round_filter input=16 output=16
# I0213 16:45:41.355185 16492 efficientnet_model.py:144] round_filter input=24 output=24
# I0213 16:45:41.566072 16492 efficientnet_model.py:144] round_filter input=24 output=24
# I0213 16:45:41.566072 16492 efficientnet_model.py:144] round_filter input=40 output=40
# I0213 16:45:41.779942 16492 efficientnet_model.py:144] round_filter input=40 output=40
# I0213 16:45:41.780941 16492 efficientnet_model.py:144] round_filter input=80 output=80
# I0213 16:45:42.068783 16492 efficientnet_model.py:144] round_filter input=80 output=80
# I0213 16:45:42.068783 16492 efficientnet_model.py:144] round_filter input=112 output=112
# I0213 16:45:42.345620 16492 efficientnet_model.py:144] round_filter input=112 output=112
# I0213 16:45:42.345620 16492 efficientnet_model.py:144] round_filter input=192 output=192
# I0213 16:45:42.697408 16492 efficientnet_model.py:144] round_filter input=192 output=192
# I0213 16:45:42.697408 16492 efficientnet_model.py:144] round_filter input=320 output=320
# I0213 16:45:42.833341 16492 efficientnet_model.py:144] round_filter input=1280 output=1280
# I0213 16:45:42.861331 16492 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0213 16:45:42.918292 16492 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0213 16:45:42.918292 16492 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 112
# I0213 16:45:42.918292 16492 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 5
# I0213 16:45:42.920291 16492 efficientnet_model.py:144] round_filter input=32 output=32
# I0213 16:45:42.934285 16492 efficientnet_model.py:144] round_filter input=32 output=32
# I0213 16:45:42.934285 16492 efficientnet_model.py:144] round_filter input=16 output=16
# I0213 16:45:43.043221 16492 efficientnet_model.py:144] round_filter input=16 output=16
# I0213 16:45:43.043221 16492 efficientnet_model.py:144] round_filter input=24 output=24
# I0213 16:45:43.257098 16492 efficientnet_model.py:144] round_filter input=24 output=24
# I0213 16:45:43.257098 16492 efficientnet_model.py:144] round_filter input=40 output=48
# I0213 16:45:43.610887 16492 efficientnet_model.py:144] round_filter input=40 output=48
# I0213 16:45:43.610887 16492 efficientnet_model.py:144] round_filter input=80 output=88
# I0213 16:45:43.897733 16492 efficientnet_model.py:144] round_filter input=80 output=88
# I0213 16:45:43.897733 16492 efficientnet_model.py:144] round_filter input=112 output=120
# I0213 16:45:44.173575 16492 efficientnet_model.py:144] round_filter input=112 output=120
# I0213 16:45:44.173575 16492 efficientnet_model.py:144] round_filter input=192 output=208
# I0213 16:45:44.524365 16492 efficientnet_model.py:144] round_filter input=192 output=208
# I0213 16:45:44.524365 16492 efficientnet_model.py:144] round_filter input=320 output=352
# I0213 16:45:44.662296 16492 efficientnet_model.py:144] round_filter input=1280 output=1408
# I0213 16:45:44.690271 16492 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0213 16:45:44.753234 16492 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0213 16:45:44.753234 16492 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 160
# I0213 16:45:44.753234 16492 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 6
# I0213 16:45:44.754244 16492 efficientnet_model.py:144] round_filter input=32 output=40
# I0213 16:45:44.769235 16492 efficientnet_model.py:144] round_filter input=32 output=40
# I0213 16:45:44.769235 16492 efficientnet_model.py:144] round_filter input=16 output=24
# I0213 16:45:44.878163 16492 efficientnet_model.py:144] round_filter input=16 output=24
# I0213 16:45:44.879163 16492 efficientnet_model.py:144] round_filter input=24 output=32
# I0213 16:45:45.091058 16492 efficientnet_model.py:144] round_filter input=24 output=32
# I0213 16:45:45.091058 16492 efficientnet_model.py:144] round_filter input=40 output=48
# I0213 16:45:45.294935 16492 efficientnet_model.py:144] round_filter input=40 output=48
# I0213 16:45:45.294935 16492 efficientnet_model.py:144] round_filter input=80 output=96
# I0213 16:45:45.643735 16492 efficientnet_model.py:144] round_filter input=80 output=96
# I0213 16:45:45.643735 16492 efficientnet_model.py:144] round_filter input=112 output=136
# I0213 16:45:45.997533 16492 efficientnet_model.py:144] round_filter input=112 output=136
# I0213 16:45:45.997533 16492 efficientnet_model.py:144] round_filter input=192 output=232
# I0213 16:45:46.416297 16492 efficientnet_model.py:144] round_filter input=192 output=232
# I0213 16:45:46.417296 16492 efficientnet_model.py:144] round_filter input=320 output=384
# I0213 16:45:46.558204 16492 efficientnet_model.py:144] round_filter input=1280 output=1536
# I0213 16:45:46.584198 16492 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0213 16:45:46.648162 16492 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0213 16:45:46.648162 16492 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 224
# I0213 16:45:46.648162 16492 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 7
# I0213 16:45:46.650151 16492 efficientnet_model.py:144] round_filter input=32 output=48
# I0213 16:45:46.665143 16492 efficientnet_model.py:144] round_filter input=32 output=48
# I0213 16:45:46.665143 16492 efficientnet_model.py:144] round_filter input=16 output=24
# I0213 16:45:46.778088 16492 efficientnet_model.py:144] round_filter input=16 output=24
# I0213 16:45:46.778088 16492 efficientnet_model.py:144] round_filter input=24 output=32
# I0213 16:45:47.064914 16492 efficientnet_model.py:144] round_filter input=24 output=32
# I0213 16:45:47.064914 16492 efficientnet_model.py:144] round_filter input=40 output=56
# I0213 16:45:47.342756 16492 efficientnet_model.py:144] round_filter input=40 output=56
# I0213 16:45:47.342756 16492 efficientnet_model.py:144] round_filter input=80 output=112
# I0213 16:45:47.975394 16492 efficientnet_model.py:144] round_filter input=80 output=112
# I0213 16:45:47.975394 16492 efficientnet_model.py:144] round_filter input=112 output=160
# I0213 16:45:48.397163 16492 efficientnet_model.py:144] round_filter input=112 output=160
# I0213 16:45:48.397163 16492 efficientnet_model.py:144] round_filter input=192 output=272
# I0213 16:45:48.966845 16492 efficientnet_model.py:144] round_filter input=192 output=272
# I0213 16:45:48.966845 16492 efficientnet_model.py:144] round_filter input=320 output=448
# I0213 16:45:49.107764 16492 efficientnet_model.py:144] round_filter input=1280 output=1792
# I0213 16:45:49.134742 16492 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0213 16:45:49.208700 16492 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0213 16:45:49.208700 16492 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 288
# I0213 16:45:49.208700 16492 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 7
# I0213 16:45:49.210698 16492 efficientnet_model.py:144] round_filter input=32 output=48
# I0213 16:45:49.224690 16492 efficientnet_model.py:144] round_filter input=32 output=48
# I0213 16:45:49.224690 16492 efficientnet_model.py:144] round_filter input=16 output=24
# I0213 16:45:49.388597 16492 efficientnet_model.py:144] round_filter input=16 output=24
# I0213 16:45:49.388597 16492 efficientnet_model.py:144] round_filter input=24 output=40
# I0213 16:45:49.739396 16492 efficientnet_model.py:144] round_filter input=24 output=40
# I0213 16:45:49.739396 16492 efficientnet_model.py:144] round_filter input=40 output=64
# I0213 16:45:50.088188 16492 efficientnet_model.py:144] round_filter input=40 output=64
# I0213 16:45:50.088188 16492 efficientnet_model.py:144] round_filter input=80 output=128
# I0213 16:45:50.573921 16492 efficientnet_model.py:144] round_filter input=80 output=128
# I0213 16:45:50.573921 16492 efficientnet_model.py:144] round_filter input=112 output=176
# I0213 16:45:51.070636 16492 efficientnet_model.py:144] round_filter input=112 output=176
# I0213 16:45:51.070636 16492 efficientnet_model.py:144] round_filter input=192 output=304
# I0213 16:45:51.706280 16492 efficientnet_model.py:144] round_filter input=192 output=304
# I0213 16:45:51.706280 16492 efficientnet_model.py:144] round_filter input=320 output=512
# I0213 16:45:51.918142 16492 efficientnet_model.py:144] round_filter input=1280 output=2048
# I0213 16:45:52.136028 16492 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0213 16:45:52.220979 16492 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0213 16:45:52.220979 16492 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 384
# I0213 16:45:52.220979 16492 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 8
# I0213 16:45:52.221978 16492 efficientnet_model.py:144] round_filter input=32 output=56
# I0213 16:45:52.236961 16492 efficientnet_model.py:144] round_filter input=32 output=56
# I0213 16:45:52.236961 16492 efficientnet_model.py:144] round_filter input=16 output=32
# I0213 16:45:52.401875 16492 efficientnet_model.py:144] round_filter input=16 output=32
# I0213 16:45:52.401875 16492 efficientnet_model.py:144] round_filter input=24 output=40
# I0213 16:45:52.825634 16492 efficientnet_model.py:144] round_filter input=24 output=40
# I0213 16:45:52.825634 16492 efficientnet_model.py:144] round_filter input=40 output=72
# I0213 16:45:53.248392 16492 efficientnet_model.py:144] round_filter input=40 output=72
# I0213 16:45:53.248392 16492 efficientnet_model.py:144] round_filter input=80 output=144
# I0213 16:45:53.817057 16492 efficientnet_model.py:144] round_filter input=80 output=144
# I0213 16:45:53.817057 16492 efficientnet_model.py:144] round_filter input=112 output=200
# I0213 16:45:54.382746 16492 efficientnet_model.py:144] round_filter input=112 output=200
# I0213 16:45:54.383746 16492 efficientnet_model.py:144] round_filter input=192 output=344
# I0213 16:45:55.161300 16492 efficientnet_model.py:144] round_filter input=192 output=344
# I0213 16:45:55.161300 16492 efficientnet_model.py:144] round_filter input=320 output=576
# I0213 16:45:55.367189 16492 efficientnet_model.py:144] round_filter input=1280 output=2304
# I0213 16:45:55.393167 16492 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0213 16:45:55.493111 16492 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0213 16:45:55.494100 16492 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 384
# I0213 16:45:55.494100 16492 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 8
# I0213 16:45:55.495100 16492 efficientnet_model.py:144] round_filter input=32 output=64
# I0213 16:45:55.509092 16492 efficientnet_model.py:144] round_filter input=32 output=64
# I0213 16:45:55.509092 16492 efficientnet_model.py:144] round_filter input=16 output=32
# I0213 16:45:55.736971 16492 efficientnet_model.py:144] round_filter input=16 output=32
# I0213 16:45:55.736971 16492 efficientnet_model.py:144] round_filter input=24 output=48
# I0213 16:45:56.222694 16492 efficientnet_model.py:144] round_filter input=24 output=48
# I0213 16:45:56.222694 16492 efficientnet_model.py:144] round_filter input=40 output=80
# I0213 16:45:56.996253 16492 efficientnet_model.py:144] round_filter input=40 output=80
# I0213 16:45:56.996253 16492 efficientnet_model.py:144] round_filter input=80 output=160
# I0213 16:45:57.698857 16492 efficientnet_model.py:144] round_filter input=80 output=160
# I0213 16:45:57.698857 16492 efficientnet_model.py:144] round_filter input=112 output=224
# I0213 16:45:58.393454 16492 efficientnet_model.py:144] round_filter input=112 output=224
# I0213 16:45:58.393454 16492 efficientnet_model.py:144] round_filter input=192 output=384
# I0213 16:45:59.299936 16492 efficientnet_model.py:144] round_filter input=192 output=384
# I0213 16:45:59.299936 16492 efficientnet_model.py:144] round_filter input=320 output=640
# I0213 16:45:59.582775 16492 efficientnet_model.py:144] round_filter input=1280 output=2560
# I0213 16:45:59.609760 16492 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 20.0s
# I0213 16:45:59.733695 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 20.0s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0213 16:45:59.739691 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0213 16:45:59.741690 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0213 16:45:59.742690 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0213 16:45:59.743690 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0213 16:45:59.745682 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0213 16:45:59.745682 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0213 16:45:59.746687 16492 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 25.400s
#
# OK (skipped=1)

# %%
# import object_detection

# %%
# if os.name =='posix':
#    !wget {PRETRAINED_MODEL_URL}
#    !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
#    !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
#if os.name == 'nt':
#    wget.download(PRETRAINED_MODEL_URL)
#    !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
#    !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}

# %%
labels = [{'name':'A', 'id':1},{'name':'B', 'id':2},{'name':'C', 'id':3},{'name':'D', 'id':4},{'name':'E', 'id':5},{'name':'F', 'id':6},{'name':'G', 'id':7},
{'name':'H', 'id':8},{'name':'I', 'id':9},{'name':'J', 'id':10},{'name':'K', 'id':11},{'name':'L', 'id':12},{'name':'M', 'id':13},{'name':'N', 'id':14},
{'name':'O', 'id':15},{'name':'P', 'id':16},{'name':'Q', 'id':17},{'name':'R', 'id':18},{'name':'S', 'id':19},{'name':'T', 'id':20},{'name':'U', 'id':21},
{'name':'V', 'id':22},{'name':'W', 'id':23},{'name':'X', 'id':24},{'name':'Y', 'id':25},{'name':'Z', 'id':26},{'name':'00', 'id':27},
{'name':'01', 'id':28},{'name':'02', 'id':29},{'name':'03', 'id':30},{'name':'04', 'id':31},{'name':'05', 'id':32},{'name':'06', 'id':33},
{'name':'07', 'id':34},{'name':'08', 'id':35},{'name':'09', 'id':36}]
          
with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
   # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=100000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet_tuned --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_tuned\pipeline.config --num_train_steps=100000

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet_tuned --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_tuned\pipeline.config --checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet_tuned

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-101')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', '5_150.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.6,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.6,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [31], in <module>
#       7 image_np = np.array(frame)
#       9 input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
# ---> 10 detections = detect_fn(input_tensor)
#      12 num_detections = int(detections.pop('num_detections'))
#      13 detections = {key: value[0, :num_detections].numpy()
#      14               for key, value in detections.items()}
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\eager\def_function.py:910, in Function.__call__(self, *args, **kwds)
#     907 compiler = "xla" if self._jit_compile else "nonXla"
#     909 with OptionalXlaContext(self._jit_compile):
# --> 910   result = self._call(*args, **kwds)
#     912 new_tracing_count = self.experimental_get_tracing_count()
#     913 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\eager\def_function.py:942, in Function._call(self, *args, **kwds)
#     939   self._lock.release()
#     940   # In this case we have created variables on the first call, so we run the
#     941   # defunned version which is guaranteed to never create variables.
# --> 942   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943 elif self._stateful_fn is not None:
#     944   # Release the lock early so that multiple threads can perform the call
#     945   # in parallel.
#     946   self._lock.release()
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\eager\function.py:3129, in Function.__call__(self, *args, **kwargs)
#    3126 """Calls a graph function specialized to the inputs."""
#    3127 with self._lock:
#    3128   (graph_function,
# -> 3129    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3130 return graph_function._call_flat(
#    3131     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\eager\function.py:3557, in Function._maybe_define_function(self, args, kwargs)
#    3553   return self._define_function_with_shape_relaxation(
#    3554       args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3556 self._function_cache.missed.add(call_context_key)
# -> 3557 graph_function = self._create_graph_function(args, kwargs)
#    3558 self._function_cache.primary[cache_key] = graph_function
#    3560 return graph_function, filtered_flat_args
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\eager\function.py:3392, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3387 missing_arg_names = [
#    3388     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3389 ]
#    3390 arg_names = base_arg_names + missing_arg_names
#    3391 graph_function = ConcreteFunction(
# -> 3392     func_graph_module.func_graph_from_py_func(
#    3393         self._name,
#    3394         self._python_function,
#    3395         args,
#    3396         kwargs,
#    3397         self.input_signature,
#    3398         autograph=self._autograph,
#    3399         autograph_options=self._autograph_options,
#    3400         arg_names=arg_names,
#    3401         override_flat_arg_shapes=override_flat_arg_shapes,
#    3402         capture_by_value=self._capture_by_value),
#    3403     self._function_attributes,
#    3404     function_spec=self.function_spec,
#    3405     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3406     # scope. This is not the default behavior since it gets used in some
#    3407     # places (like Keras) where the FuncGraph lives longer than the
#    3408     # ConcreteFunction.
#    3409     shared_func_graph=False)
#    3410 return graph_function
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\framework\func_graph.py:1143, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1140 else:
#    1141   _, original_func = tf_decorator.unwrap(python_func)
# -> 1143 func_outputs = python_func(*func_args, **func_kwargs)
#    1145 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1146 # TensorArrays and `None`s.
#    1147 func_outputs = nest.map_structure(convert, func_outputs,
#    1148                                   expand_composites=True)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\eager\def_function.py:672, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     668 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     669   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     670   # the function a weak reference to itself to avoid a reference cycle.
#     671   with OptionalXlaContext(compile_with_xla):
# --> 672     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673   return out
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\framework\func_graph.py:1118, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1116 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1117 try:
# -> 1118   return autograph.converted_call(
#    1119       original_func,
#    1120       args,
#    1121       kwargs,
#    1122       options=autograph.ConversionOptions(
#    1123           recursive=True,
#    1124           optional_features=autograph_options,
#    1125           user_requested=True,
#    1126       ))
#    1127 except Exception as e:  # pylint:disable=broad-except
#    1128   if hasattr(e, "ag_error_metadata"):
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:445, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     443 try:
#     444   if kwargs is not None:
# --> 445     result = converted_f(*effective_args, **kwargs)
#     446   else:
#     447     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_filexeeueb67.py:12, in outer_factory.<locals>.inner_factory.<locals>.tf__detect_fn(image)
#      10 (image, shapes) = ag__.converted_call(ag__.ld(detection_model).preprocess, (ag__.ld(image),), None, fscope)
#      11 prediction_dict = ag__.converted_call(ag__.ld(detection_model).predict, (ag__.ld(image), ag__.ld(shapes)), None, fscope)
# ---> 12 detections = ag__.converted_call(ag__.ld(detection_model).postprocess, (ag__.ld(prediction_dict), ag__.ld(shapes)), None, fscope)
#      13 try:
#      14     do_return = True
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:447, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     445     result = converted_f(*effective_args, **kwargs)
#     446   else:
# --> 447     result = converted_f(*effective_args)
#     448 except Exception as e:
#     449   _attach_error_metadata(e, converted_f)
#
# File ~\AppData\Local\Temp\__autograph_generated_file5zolyo3e.py:132, in outer_factory.<locals>.inner_factory.<locals>.tf__postprocess(self, prediction_dict, true_image_shapes)
#     130     pass
#     131 ag__.if_stmt((ag__.ld(detection_keypoints) is not None), if_body_5, else_body_5, get_state_6, set_state_6, ('additional_fields[fields.BoxListFields.keypoints]', 'detection_keypoints'), 1)
# --> 132 (nmsed_boxes, nmsed_scores, nmsed_classes, nmsed_masks, nmsed_additional_fields, num_detections) = ag__.converted_call(ag__.ld(self)._non_max_suppression_fn, (ag__.ld(detection_boxes), ag__.ld(detection_scores)), dict(clip_window=ag__.converted_call(ag__.ld(self)._compute_clip_window, (ag__.ld(preprocessed_images), ag__.ld(true_image_shapes)), None, fscope), additional_fields=ag__.ld(additional_fields), masks=ag__.converted_call(ag__.ld(prediction_dict).get, ('mask_predictions',), None, fscope)), fscope)
#     133 detection_dict = {ag__.ld(fields).DetectionResultFields.detection_boxes: ag__.ld(nmsed_boxes), ag__.ld(fields).DetectionResultFields.detection_scores: ag__.ld(nmsed_scores), ag__.ld(fields).DetectionResultFields.detection_classes: ag__.ld(nmsed_classes), ag__.ld(fields).DetectionResultFields.num_detections: ag__.converted_call(ag__.ld(tf).cast, (ag__.ld(num_detections),), dict(dtype=ag__.ld(tf).float32), fscope), ag__.ld(fields).DetectionResultFields.raw_detection_boxes: ag__.converted_call(ag__.ld(tf).squeeze, (ag__.ld(detection_boxes),), dict(axis=2), fscope), ag__.ld(fields).DetectionResultFields.raw_detection_scores: ag__.ld(detection_scores_with_background)}
#     135 def get_state_7():
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:358, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     355   new_args = f.args + args
#     356   logging.log(3, 'Forwarding call of partial %s with\n%s\n%s\n', f, new_args,
#     357               new_kwargs)
# --> 358   return converted_call(
#     359       f.func,
#     360       new_args,
#     361       new_kwargs,
#     362       caller_fn_scope=caller_fn_scope,
#     363       options=options)
#     365 if inspect_utils.isbuiltin(f):
#     366   if f is eval:
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:445, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     443 try:
#     444   if kwargs is not None:
# --> 445     result = converted_f(*effective_args, **kwargs)
#     446   else:
#     447     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_filefr4sxabi.py:596, in outer_factory.<locals>.inner_factory.<locals>.tf__batch_multiclass_non_max_suppression(boxes, scores, score_thresh, iou_thresh, max_size_per_class, max_total_size, clip_window, change_coordinate_frame, num_valid_boxes, masks, additional_fields, soft_nms_sigma, scope, use_static_shapes, use_partitioned_nms, parallel_iterations, use_class_agnostic_nms, max_classes_per_detection, use_dynamic_map_fn, use_combined_nms, use_hard_nms, use_cpu_nms)
#     594 batch_num_detections = ag__.Undefined('batch_num_detections')
#     595 batch_size = ag__.Undefined('batch_size')
# --> 596 ag__.if_stmt(ag__.ld(use_combined_nms), if_body_29, else_body_29, get_state_32, set_state_32, ('do_return', 'num_classes', 'ordered_additional_fields', 'q', 'retval_', 'clip_window', 'masks', 'num_valid_boxes'), 5)
#     597 return fscope.ret(retval_, do_return)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:1324, in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1322   _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1323 else:
# -> 1324   _py_if_stmt(cond, body, orelse)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:1377, in _py_if_stmt(cond, body, orelse)
#    1375 def _py_if_stmt(cond, body, orelse):
#    1376   """Overload of if_stmt that executes a Python if statement."""
# -> 1377   return body() if cond else orelse()
#
# File ~\AppData\Local\Temp\__autograph_generated_filefr4sxabi.py:501, in outer_factory.<locals>.inner_factory.<locals>.tf__batch_multiclass_non_max_suppression.<locals>.else_body_29()
#     499 map_fn = ag__.Undefined('map_fn')
#     500 ag__.if_stmt(ag__.ld(use_dynamic_map_fn), if_body_25, else_body_25, get_state_27, set_state_27, ('map_fn',), 1)
# --> 501 batch_outputs = ag__.converted_call(ag__.ld(map_fn), (ag__.ld(_single_image_nms_fn),), dict(elems=(([ag__.ld(boxes), ag__.ld(scores), ag__.ld(masks), ag__.ld(clip_window)] + ag__.converted_call(ag__.ld(list), (ag__.converted_call(ag__.ld(ordered_additional_fields).values, (), None, fscope),), None, fscope)) + [ag__.ld(num_valid_boxes)]), dtype=((ag__.ld(num_nmsed_outputs) * [ag__.ld(tf).float32]) + [ag__.ld(tf).int32]), parallel_iterations=ag__.ld(parallel_iterations)), fscope)
#     502 batch_nmsed_boxes = ag__.ld(batch_outputs)[0]
#     503 batch_nmsed_scores = ag__.ld(batch_outputs)[1]
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:445, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     443 try:
#     444   if kwargs is not None:
# --> 445     result = converted_f(*effective_args, **kwargs)
#     446   else:
#     447     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_filenrgl7znr.py:149, in outer_factory.<locals>.inner_factory.<locals>.tf__static_or_dynamic_map_fn(fn, elems, dtype, parallel_iterations, back_prop)
#     147 outputs = ag__.Undefined('outputs')
#     148 arg_tuples = ag__.Undefined('arg_tuples')
# --> 149 ag__.if_stmt(ag__.converted_call(ag__.ld(isinstance), (ag__.ld(elems), ag__.ld(list)), None, fscope), if_body_5, else_body_5, get_state_7, set_state_7, ('do_return', 'outputs', 'retval_'), 3)
#     151 def get_state_12():
#     152     return (do_return, retval_)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:1324, in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1322   _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1323 else:
# -> 1324   _py_if_stmt(cond, body, orelse)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:1377, in _py_if_stmt(cond, body, orelse)
#    1375 def _py_if_stmt(cond, body, orelse):
#    1376   """Overload of if_stmt that executes a Python if statement."""
# -> 1377   return body() if cond else orelse()
#
# File ~\AppData\Local\Temp\__autograph_generated_filenrgl7znr.py:103, in outer_factory.<locals>.inner_factory.<locals>.tf__static_or_dynamic_map_fn.<locals>.if_body_5()
#     101 outputs = ag__.Undefined('outputs')
#     102 arg_tuples = ag__.Undefined('arg_tuples')
# --> 103 ag__.if_stmt(ag__.not_(do_return), if_body_2, else_body_2, get_state_4, set_state_4, ('outputs',), 1)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:1324, in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1322   _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1323 else:
# -> 1324   _py_if_stmt(cond, body, orelse)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:1377, in _py_if_stmt(cond, body, orelse)
#    1375 def _py_if_stmt(cond, body, orelse):
#    1376   """Overload of if_stmt that executes a Python if statement."""
# -> 1377   return body() if cond else orelse()
#
# File ~\AppData\Local\Temp\__autograph_generated_filenrgl7znr.py:96, in outer_factory.<locals>.inner_factory.<locals>.tf__static_or_dynamic_map_fn.<locals>.if_body_5.<locals>.if_body_2()
#      94 nonlocal outputs
#      95 arg_tuples = ag__.converted_call(ag__.ld(zip), tuple([ag__.converted_call(ag__.ld(tf).unstack, (ag__.ld(elem),), None, fscope) for elem in ag__.ld(elems)]), None, fscope)
# ---> 96 outputs = [ag__.converted_call(ag__.ld(fn), (ag__.ld(arg_tuple),), None, fscope) for arg_tuple in ag__.ld(arg_tuples)]
#
# File ~\AppData\Local\Temp\__autograph_generated_filenrgl7znr.py:96, in <listcomp>(.0)
#      94 nonlocal outputs
#      95 arg_tuples = ag__.converted_call(ag__.ld(zip), tuple([ag__.converted_call(ag__.ld(tf).unstack, (ag__.ld(elem),), None, fscope) for elem in ag__.ld(elems)]), None, fscope)
# ---> 96 outputs = [ag__.converted_call(ag__.ld(fn), (ag__.ld(arg_tuple),), None, fscope) for arg_tuple in ag__.ld(arg_tuples)]
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:345, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     343 if is_autograph_artifact(f):
#     344   logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 345   return _call_unconverted(f, args, kwargs, options)
#     347 # If this is a partial, unwrap it and redo all the checks.
#     348 if isinstance(f, functools.partial):
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:465, in _call_unconverted(f, args, kwargs, options, update_cache)
#     463 if kwargs is not None:
#     464   return f(*args, **kwargs)
# --> 465 return f(*args)
#
# File ~\AppData\Local\Temp\__autograph_generated_filefr4sxabi.py:425, in outer_factory.<locals>.inner_factory.<locals>.tf__batch_multiclass_non_max_suppression.<locals>.else_body_29.<locals>._single_image_nms_fn(args)
#     423 nmsed_boxlist = ag__.Undefined('nmsed_boxlist')
#     424 num_valid_nms_boxes = ag__.Undefined('num_valid_nms_boxes')
# --> 425 ag__.if_stmt(ag__.ld(use_class_agnostic_nms), if_body_22, else_body_22, get_state_23, set_state_23, ('nmsed_boxlist', 'num_valid_nms_boxes'), 2)
#     427 def get_state_24():
#     428     return (nmsed_boxlist,)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:1324, in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1322   _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1323 else:
# -> 1324   _py_if_stmt(cond, body, orelse)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:1377, in _py_if_stmt(cond, body, orelse)
#    1375 def _py_if_stmt(cond, body, orelse):
#    1376   """Overload of if_stmt that executes a Python if statement."""
# -> 1377   return body() if cond else orelse()
#
# File ~\AppData\Local\Temp\__autograph_generated_filefr4sxabi.py:422, in outer_factory.<locals>.inner_factory.<locals>.tf__batch_multiclass_non_max_suppression.<locals>.else_body_29.<locals>._single_image_nms_fn.<locals>.else_body_22()
#     420 def else_body_22():
#     421     nonlocal nmsed_boxlist, num_valid_nms_boxes
# --> 422     (nmsed_boxlist, num_valid_nms_boxes) = ag__.converted_call(ag__.ld(multiclass_non_max_suppression), (ag__.ld(per_image_boxes), ag__.ld(per_image_scores), ag__.ld(score_thresh), ag__.ld(iou_thresh), ag__.ld(max_size_per_class), ag__.ld(max_total_size)), dict(clip_window=ag__.ld(per_image_clip_window), change_coordinate_frame=ag__.ld(change_coordinate_frame), masks=ag__.ld(per_image_masks), pad_to_max_output_size=ag__.ld(use_static_shapes), use_partitioned_nms=ag__.ld(use_partitioned_nms), additional_fields=ag__.ld(per_image_additional_fields), soft_nms_sigma=ag__.ld(soft_nms_sigma), use_hard_nms=ag__.ld(use_hard_nms), use_cpu_nms=ag__.ld(use_cpu_nms)), fscope_1)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:445, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     443 try:
#     444   if kwargs is not None:
# --> 445     result = converted_f(*effective_args, **kwargs)
#     446   else:
#     447     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_file2lg3fzbh.py:229, in outer_factory.<locals>.inner_factory.<locals>.tf__multiclass_non_max_suppression(boxes, scores, score_thresh, iou_thresh, max_size_per_class, max_total_size, clip_window, change_coordinate_frame, masks, boundaries, pad_to_max_output_size, use_partitioned_nms, additional_fields, soft_nms_sigma, use_hard_nms, use_cpu_nms, scope)
#     227 selected_indices = ag__.Undefined('selected_indices')
#     228 ag__.for_stmt(ag__.converted_call(ag__.ld(zip), (ag__.converted_call(ag__.ld(range), (ag__.ld(num_classes),), None, fscope), ag__.ld(boxes_ids)), None, fscope), None, loop_body_1, get_state_11, set_state_11, ('num_valid_nms_boxes_cumulative',), {'iterate_names': '(class_idx, boxes_idx)'})
# --> 229 selected_boxes = ag__.converted_call(ag__.ld(box_list_ops).concatenate, (ag__.ld(selected_boxes_list),), None, fscope)
#     230 sorted_boxes = ag__.converted_call(ag__.ld(box_list_ops).sort_by_field, (ag__.ld(selected_boxes), ag__.ld(fields).BoxListFields.scores), None, fscope)
#     232 def get_state_12():
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:447, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     445     result = converted_f(*effective_args, **kwargs)
#     446   else:
# --> 447     result = converted_f(*effective_args)
#     448 except Exception as e:
#     449   _attach_error_metadata(e, converted_f)
#
# File ~\AppData\Local\Temp\__autograph_generated_filevb2km4c0.py:148, in outer_factory.<locals>.inner_factory.<locals>.tf__concatenate(boxlists, fields, scope)
#     146 field_shape = ag__.Undefined('field_shape')
#     147 field = ag__.Undefined('field')
# --> 148 ag__.for_stmt(ag__.ld(fields), None, loop_body_2, get_state_9, set_state_9, (), {'iterate_names': 'field'})
#     149 try:
#     150     do_return = True
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:444, in for_stmt(iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#     440   _tf_distributed_iterable_for_stmt(
#     441       iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#     443 else:
# --> 444   _py_for_stmt(iter_, extra_test, body, None, None)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:493, in _py_for_stmt(***failed resolving arguments***)
#     491 else:
#     492   for target in iter_:
# --> 493     body(target)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:459, in _py_for_stmt.<locals>.protected_body(protected_iter)
#     458 def protected_body(protected_iter):
# --> 459   original_body(protected_iter)
#     460   after_iteration()
#     461   before_iteration()
#
# File ~\AppData\Local\Temp\__autograph_generated_filevb2km4c0.py:141, in outer_factory.<locals>.inner_factory.<locals>.tf__concatenate.<locals>.loop_body_2(itr_2)
#     139         pass
#     140     ag__.if_stmt((ag__.ld(field_shape) != ag__.ld(first_field_shape)), if_body_6, else_body_6, get_state_7, set_state_7, (), 0)
# --> 141 ag__.for_stmt(ag__.ld(boxlists), None, loop_body_1, get_state_8, set_state_8, (), {'iterate_names': 'boxlist'})
#     142 concatenated_field = ag__.converted_call(ag__.ld(tf).concat, ([ag__.converted_call(ag__.ld(boxlist).get_field, (ag__.ld(field),), None, fscope) for boxlist in ag__.ld(boxlists)], 0), None, fscope)
#     143 ag__.converted_call(ag__.ld(concatenated).add_field, (ag__.ld(field), ag__.ld(concatenated_field)), None, fscope)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:444, in for_stmt(iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#     440   _tf_distributed_iterable_for_stmt(
#     441       iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#     443 else:
# --> 444   _py_for_stmt(iter_, extra_test, body, None, None)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:493, in _py_for_stmt(***failed resolving arguments***)
#     491 else:
#     492   for target in iter_:
# --> 493     body(target)
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:459, in _py_for_stmt.<locals>.protected_body(protected_iter)
#     458 def protected_body(protected_iter):
# --> 459   original_body(protected_iter)
#     460   after_iteration()
#     461   before_iteration()
#
# File ~\AppData\Local\Temp\__autograph_generated_filevb2km4c0.py:126, in outer_factory.<locals>.inner_factory.<locals>.tf__concatenate.<locals>.loop_body_2.<locals>.loop_body_1(itr_1)
#     124     pass
#     125 ag__.if_stmt(ag__.not_(ag__.converted_call(ag__.ld(boxlist).has_field, (ag__.ld(field),), None, fscope)), if_body_5, else_body_5, get_state_6, set_state_6, (), 0)
# --> 126 field_shape = ag__.converted_call(ag__.converted_call(ag__.converted_call(ag__.ld(boxlist).get_field, (ag__.ld(field),), None, fscope).get_shape, (), None, fscope).as_list, (), None, fscope)
#     127 ag__.ld(field_shape)[0] = (- 1)
#     129 def get_state_7():
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:442, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     439     raise
#     440   return _fall_back_unconverted(f, args, kwargs, options, e)
# --> 442 with StackTraceMapper(converted_f), tf_stack.CurrentModuleFilter():
#     443   try:
#     444     if kwargs is not None:
#
# File c:\users\amit\desktop\beproject\tfod\lib\site-packages\tensorflow\python\util\tf_stack.py:138, in CurrentModuleFilter.__init__(self)
#     136   outer_f = f.f_back
#     137   if outer_f is not None:
# --> 138     filter_filename = inspect.getsourcefile(outer_f)
#     139 self._filename = filter_filename
#     140 # This may be called repeatedly: once on entry by the superclass, then by
#     141 # each child context manager.
#
# File C:\Program Files\Python38\lib\inspect.py:705, in getsourcefile(object)
#     702 elif any(filename.endswith(s) for s in
#     703              importlib.machinery.EXTENSION_SUFFIXES):
#     704     return None
# --> 705 if os.path.exists(filename):
#     706     return filename
#     707 # only return a non-existent filename if the module has a PEP 302 loader
#
# File C:\Program Files\Python38\lib\genericpath.py:19, in exists(path)
#      17 """Test whether a path exists.  Returns False for broken symbolic links"""
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#      21     return False
#
# KeyboardInterrupt:

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_tuned\pipeline.config --trained_checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet_tuned --output_directory=Tensorflow\workspace\models\my_ssd_mobnet_tuned\export

# %%
# !{command}
# Out:
# 2022-02-13 16:47:54.033444: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-13 16:47:54.704578: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3870 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660, pci bus id: 0000:01:00.0, compute capability: 7.5
# WARNING:tensorflow:From C:\Users\Amit\Desktop\BEProject\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:464: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0213 16:47:56.078179  4116 deprecation.py:614] From C:\Users\Amit\Desktop\BEProject\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:464: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x0000024905022CD0>, because it is not built.
# W0213 16:48:25.356419  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x0000024905022CD0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x00000249095D7B50>, because it is not built.
# W0213 16:48:25.487338  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x00000249095D7B50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249095F8A00>, because it is not built.
# W0213 16:48:25.488338  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249095F8A00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249095F8F10>, because it is not built.
# W0213 16:48:25.488338  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249095F8F10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x00000249096671C0>, because it is not built.
# W0213 16:48:25.488338  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x00000249096671C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000024909667AC0>, because it is not built.
# W0213 16:48:25.488338  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000024909667AC0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909667C70>, because it is not built.
# W0213 16:48:25.488338  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909667C70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x0000024909667B50>, because it is not built.
# W0213 16:48:25.488338  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x0000024909667B50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002490966B7C0>, because it is not built.
# W0213 16:48:25.488338  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002490966B7C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000002490966B850>, because it is not built.
# W0213 16:48:25.488338  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000002490966B850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000002490966BD00>, because it is not built.
# W0213 16:48:25.488338  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000002490966BD00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002490966B8E0>, because it is not built.
# W0213 16:48:25.488338  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002490966B8E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909656520>, because it is not built.
# W0213 16:48:25.489343  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909656520>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002490570D190>, because it is not built.
# W0213 16:48:25.489343  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002490570D190>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000002490965DBB0>, because it is not built.
# W0213 16:48:25.489343  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000002490965DBB0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000024909663E20>, because it is not built.
# W0213 16:48:25.489343  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000024909663E20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909663D30>, because it is not built.
# W0213 16:48:25.489343  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909663D30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000024909663610>, because it is not built.
# W0213 16:48:25.489343  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000024909663610>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909663460>, because it is not built.
# W0213 16:48:25.489343  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909663460>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249096639D0>, because it is not built.
# W0213 16:48:25.489343  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249096639D0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909663940>, because it is not built.
# W0213 16:48:25.489343  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909663940>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002490570D1C0>, because it is not built.
# W0213 16:48:25.489343  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002490570D1C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249096CA5E0>, because it is not built.
# W0213 16:48:25.489343  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249096CA5E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249096C79A0>, because it is not built.
# W0213 16:48:25.489343  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249096C79A0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249096C7970>, because it is not built.
# W0213 16:48:25.490327  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249096C7970>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249096C7C70>, because it is not built.
# W0213 16:48:25.490327  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249096C7C70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249096C7E80>, because it is not built.
# W0213 16:48:25.490327  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249096C7E80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249096CC1F0>, because it is not built.
# W0213 16:48:25.490327  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249096CC1F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249096CC730>, because it is not built.
# W0213 16:48:25.490327  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249096CC730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002490570D1F0>, because it is not built.
# W0213 16:48:25.490327  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002490570D1F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249096C3280>, because it is not built.
# W0213 16:48:25.490327  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249096C3280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249096CF0A0>, because it is not built.
# W0213 16:48:25.490327  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249096CF0A0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249096CF9A0>, because it is not built.
# W0213 16:48:25.490327  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249096CF9A0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249096CF820>, because it is not built.
# W0213 16:48:25.490327  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249096CF820>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249096CF1C0>, because it is not built.
# W0213 16:48:25.490327  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x00000249096CF1C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002490963A5E0>, because it is not built.
# W0213 16:48:25.490327  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002490963A5E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000002490963A760>, because it is not built.
# W0213 16:48:25.490327  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000002490963A760>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249096378E0>, because it is not built.
# W0213 16:48:25.491326  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000249096378E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909637CA0>, because it is not built.
# W0213 16:48:25.491326  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909637CA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000024909627C10>, because it is not built.
# W0213 16:48:25.491326  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000024909627C10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909627370>, because it is not built.
# W0213 16:48:25.491326  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909627370>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000024909627610>, because it is not built.
# W0213 16:48:25.491326  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000024909627610>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909627670>, because it is not built.
# W0213 16:48:25.491326  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909627670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000024909578790>, because it is not built.
# W0213 16:48:25.491326  4116 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000024909578790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909578490>, because it is not built.
# W0213 16:48:25.491326  4116 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000024909578490>, because it is not built.
# 2022-02-13 16:48:36.651016: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# W0213 16:49:01.463444  4116 save.py:263] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 260). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow\workspace\models\my_ssd_mobnet_tuned\export\saved_model\assets
# I0213 16:49:09.219627  4116 builder_impl.py:783] Assets written to: Tensorflow\workspace\models\my_ssd_mobnet_tuned\export\saved_model\assets
# INFO:tensorflow:Writing pipeline config file to Tensorflow\workspace\models\my_ssd_mobnet_tuned\export\pipeline.config
# I0213 16:49:10.160477  4116 config_util.py:253] Writing pipeline config file to Tensorflow\workspace\models\my_ssd_mobnet_tuned\export\pipeline.config

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\export_tflite_graph_tf2.py  --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_tuned\pipeline.config --trained_checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet_tuned --output_directory=Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport

# %%
# !{command}
# Out:
# 2022-02-13 16:49:19.585248: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-13 16:49:20.318402: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3991 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2022-02-13 16:49:28.043191: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3991 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2022-02-13 16:49:30.349866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3991 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660, pci bus id: 0000:01:00.0, compute capability: 7.5
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x0000019FD69D3EB0>, because it is not built.
# W0213 16:49:31.229893 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x0000019FD69D3EB0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x0000019FD6A16B50>, because it is not built.
# W0213 16:49:31.379791 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x0000019FD6A16B50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF85FEE20>, because it is not built.
# W0213 16:49:31.380791 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF85FEE20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF85FEAC0>, because it is not built.
# W0213 16:49:31.380791 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF85FEAC0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x0000019FF85FE550>, because it is not built.
# W0213 16:49:31.380791 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x0000019FF85FE550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FDCE94E20>, because it is not built.
# W0213 16:49:31.380791 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FDCE94E20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF862D250>, because it is not built.
# W0213 16:49:31.380791 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF862D250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x0000019FF862D970>, because it is not built.
# W0213 16:49:31.380791 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x0000019FF862D970>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF862DA90>, because it is not built.
# W0213 16:49:31.380791 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF862DA90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF862DE80>, because it is not built.
# W0213 16:49:31.380791 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF862DE80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x0000019FF8B1B040>, because it is not built.
# W0213 16:49:31.380791 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x0000019FF8B1B040>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF8B1BD90>, because it is not built.
# W0213 16:49:31.380791 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF8B1BD90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8B1BE20>, because it is not built.
# W0213 16:49:31.381790 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8B1BE20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FDCE6E460>, because it is not built.
# W0213 16:49:31.381790 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FDCE6E460>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8B092E0>, because it is not built.
# W0213 16:49:31.381790 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8B092E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF8B1E820>, because it is not built.
# W0213 16:49:31.381790 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF8B1E820>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8B1EB80>, because it is not built.
# W0213 16:49:31.381790 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8B1EB80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF8553850>, because it is not built.
# W0213 16:49:31.381790 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF8553850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8553C70>, because it is not built.
# W0213 16:49:31.381790 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8553C70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF8553F40>, because it is not built.
# W0213 16:49:31.381790 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF8553F40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8553A00>, because it is not built.
# W0213 16:49:31.382789 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8553A00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FDCE6E490>, because it is not built.
# W0213 16:49:31.382789 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FDCE6E490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8B10BE0>, because it is not built.
# W0213 16:49:31.382789 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8B10BE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF85EE790>, because it is not built.
# W0213 16:49:31.382789 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF85EE790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF7C812E0>, because it is not built.
# W0213 16:49:31.382789 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF7C812E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF7C81880>, because it is not built.
# W0213 16:49:31.382789 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF7C81880>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF7C81D30>, because it is not built.
# W0213 16:49:31.382789 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF7C81D30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF7C81640>, because it is not built.
# W0213 16:49:31.382789 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF7C81640>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF7C81280>, because it is not built.
# W0213 16:49:31.382789 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF7C81280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FDCE6E4C0>, because it is not built.
# W0213 16:49:31.382789 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FDCE6E4C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF85EDFA0>, because it is not built.
# W0213 16:49:31.382789 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF85EDFA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF7AC7CA0>, because it is not built.
# W0213 16:49:31.382789 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF7AC7CA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF7AC7490>, because it is not built.
# W0213 16:49:31.383789 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF7AC7490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF864D8E0>, because it is not built.
# W0213 16:49:31.383789 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF864D8E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF864DBE0>, because it is not built.
# W0213 16:49:31.383789 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF864DBE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF864DD90>, because it is not built.
# W0213 16:49:31.383789 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF864DD90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF864DAF0>, because it is not built.
# W0213 16:49:31.383789 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF864DAF0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FDCF693D0>, because it is not built.
# W0213 16:49:31.383789 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FDCF693D0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF7BC5940>, because it is not built.
# W0213 16:49:31.383789 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF7BC5940>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF8604FA0>, because it is not built.
# W0213 16:49:31.383789 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF8604FA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8604FD0>, because it is not built.
# W0213 16:49:31.383789 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8604FD0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF8614790>, because it is not built.
# W0213 16:49:31.383789 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF8614790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8614C10>, because it is not built.
# W0213 16:49:31.383789 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF8614C10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF8614A30>, because it is not built.
# W0213 16:49:31.383789 17612 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000019FF8614A30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF86144F0>, because it is not built.
# W0213 16:49:31.384789 17612 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000019FF86144F0>, because it is not built.
# 2022-02-13 16:49:43.486669: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2022-02-13 16:49:45.157732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3991 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660, pci bus id: 0000:01:00.0, compute capability: 7.5
# W0213 16:50:01.249732 17612 save.py:263] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 260). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport\saved_model\assets
# I0213 16:50:08.159785 17612 builder_impl.py:783] Assets written to: Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport\saved_model\assets

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)
# Out:
# tflite_convert --saved_model_dir=Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport\saved_model --output_file=Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport\saved_model\detect.tflite --input_shapes=1,300,300,3 --input_arrays=normalized_input_image_tensor --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' --inference_type=FLOAT --allow_custom_ops

# %%
# !{command}
# Out:
# Estimated count of arithmetic ops: 7.364 G  ops, equivalently 3.682 G  MACs
# 2022-02-13 16:50:16.672012: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-13 16:50:17.391631: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3991 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2022-02-13 16:50:41.340831: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:363] Ignored output_format.
# 2022-02-13 16:50:41.340859: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:366] Ignored drop_control_dependency.
# 2022-02-13 16:50:41.340866: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:372] Ignored change_concat_input_ranges.
# 2022-02-13 16:50:41.343277: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport\saved_model
# 2022-02-13 16:50:41.549774: I tensorflow/cc/saved_model/reader.cc:107] Reading meta graph with tags { serve }
# 2022-02-13 16:50:41.549824: I tensorflow/cc/saved_model/reader.cc:148] Reading SavedModel debug info (if present) from: Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport\saved_model
# 2022-02-13 16:50:42.332211: I tensorflow/cc/saved_model/loader.cc:210] Restoring SavedModel bundle.
# 2022-02-13 16:50:44.035797: I tensorflow/cc/saved_model/loader.cc:194] Running initialization op on SavedModel bundle at path: Tensorflow\workspace\models\my_ssd_mobnet_tuned\tfliteexport\saved_model
# 2022-02-13 16:50:44.751265: I tensorflow/cc/saved_model/loader.cc:283] SavedModel load for tags { serve }; Status: success: OK. Took 3407982 microseconds.
# 2022-02-13 16:50:45.934357: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:237] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2022-02-13 16:50:47.221078: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:1962] Estimated count of arithmetic ops: 7.364 G  ops, equivalently 3.682 G  MACs
